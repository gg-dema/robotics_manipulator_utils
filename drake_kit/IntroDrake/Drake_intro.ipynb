# %%
import numpy as np
import logging 
#3D viewer from js
from pydrake.geometry import MeshcatVisualizer, StartMeshcat
from pydrake.math import RigidTransform, RotationMatrix
from pydrake.systems.analysis import Simulator 
from pydrake.systems.framework import DiagramBuilder

from manipulation import running_as_notebook
from manipulation.meshcat_utils import MeshcatPoseSliders, WsgButton 
from manipulation.scenarios import (AddIiwaDifferentialIK, 
                                   MakeManipulationStation)

# %%
meshcat = StartMeshcat() #from pydrake.geometry
# Out:
# INFO:drake:Meshcat listening for connections at http://localhost:7000

# %%
meshcat.port()
# Out:
# 7000

# %%
model_directives = """
directives:
- add_model:
    name: iiwa
    file: package://drake/manipulation/models/iiwa_description/urdf/planar_iiwa14_spheres_dense_elbow_collision.urdf
    default_joint_positions:
        iiwa_joint_2: [0.1]
        iiwa_joint_4: [-1.2]
        iiwa_joint_6: [1.6]
- add_weld:
    parent: world
    child: iiwa::iiwa_link_0
- add_model:
    name: wsg
    file: package://drake/manipulation/models/wsg_50_description/sdf/schunk_wsg_50_with_tip.sdf
- add_weld:
    parent: iiwa::iiwa_link_7
    child: wsg::body
    X_PC:
        translation: [0, 0, 0.09]
        rotation: !Rpy { deg: [90, 0, 90]}
- add_model:
    name: foam_brick
    file: package://drake/examples/manipulation_station/models/061_foam_brick.sdf
    default_free_body_pose:
        base_link:
            translation: [0.6, 0, 0]
- add_model:
    name: robot_table
    file: package://drake/examples/kuka_iiwa_arm/models/table/extra_heavy_duty_table_surface_only_collision.sdf
- add_weld:
    parent: world
    child: robot_table::link
    X_PC:
        translation: [0, 0, -0.7645]
- add_model:
    name: work_table
    file: package://drake/examples/kuka_iiwa_arm/models/table/extra_heavy_duty_table_surface_only_collision.sdf
- add_weld:
    parent: world
    child: work_table::link
    X_PC:
        translation: [0.75, 0, -0.7645]
"""

# %%
builder = DiagramBuilder()
station = builder.AddSystem(MakeManipulationStation(model_directives, time_step=0.0001))

# %%
plant = station.GetSubsystemByName('plant')

# %%
controller_plant = station.GetSubsystemByName('iiwa_controller').get_multibody_plant_for_control()
controller_plant
# Out:
# <pydrake.multibody.plant.MultibodyPlant_[float] at 0x7f86c9bcebb0>

# %%
visualizer = MeshcatVisualizer.AddToBuilder(
        builder, station.GetOutputPort("query_object"), meshcat
    )
meshcat.Set2dRenderMode(xmin=-0.25, xmax=1.5, ymin=-0.1, ymax=1.3)
meshcat.DeleteAddedControls()

# %%
def teleop_2d():
    builder = DiagramBuilder() #system.framework
    
    time_step = 0.001
    station = builder.AddSystem(
        MakeManipulationStation(model_directives, time_step=time_step)
    )
    plant = station.GetSubsystemByName('plant')
    controller_plant = station.GetSubsystemByName(
        "iiwa_controller"
    ).get_multibody_plant_for_control()
    
    
    # still from pydrake
    # rendering part: 
    visualizer = MeshcatVisualizer.AddToBuilder(
        builder, station.GetOutputPort("query_object"), meshcat
    )
    meshcat.Set2dRenderMode(xmin=-0.25, xmax=1.5, ymin=-0.1, ymax=1.3)
    meshcat.DeleteAddedControls()
    
    # Differential Inverse Kinematics part ---> q' = J^-1 * r' : 
    # addIiwaDifferentialIK comes from manipulation 
    differential_ik = AddIiwaDifferentialIK(
        builder, 
        controller_plant, 
        frame=controller_plant.GetFrameByName('iiwa_link_7')
    )
    # connect system ---> note that it's done by port
    builder.Connect(
        differential_ik.get_output_port(), 
        station.GetInputPort("iiwa_position")
    )
    builder.Connect(
        station.GetOutputPort("iiwa_state_estimated"),
        differential_ik.GetInputPort("robot_state")
    )
    
    
    # Teleop widgets: 
    teleop = builder.AddSystem(
        
        MeshcatPoseSliders(
            meshcat, 
            min_range=MeshcatPoseSliders.MinRange(roll=0, x=-0.6, z=0.0),
            max_range=MeshcatPoseSliders.MaxRange(roll=2 * np.pi, x=0.8, z=1.1),
            value=MeshcatPoseSliders.Value(pitch=0, yaw=np.pi / 2, y=0),
            visible=MeshcatPoseSliders.Visible(pitch=False, yaw=False, y=False),
            decrement_keycode=MeshcatPoseSliders.DecrementKey(
                x="ArrowLeft",
                z="ArrowDown"),
            increment_keycode=MeshcatPoseSliders.IncrementKey(
                x="ArrowRight",
                z="ArrowUp"),
            body_index=plant.GetBodyByName("iiwa_link_7").index()
        )
    )
    
    builder.Connect(
        teleop.get_output_port(0),
        differential_ik.get_input_port(0)
    )
    builder.Connect(
        station.GetOutputPort('body_poses'), 
        teleop.GetInputPort('body_poses')
    )
    # from manipulation 
    wsg_teleop = builder.AddSystem(WsgButton(meshcat))
    builder.Connect(wsg_teleop.get_output_port(0), 
                   station.GetInputPort("wsg_position"))
    
    diagram = builder.Build()
    simulator = Simulator(diagram)
    
    
    
    
    if running_as_notebook:  # Then we're not just running as a test on CI.
        simulator.set_target_realtime_rate(1.0)
        meshcat.AddButton("Stop Simulation", "Escape")
        print("Press Escape to stop the simulation")
        while meshcat.GetButtonClicks("Stop Simulation") < 1:
            simulator.AdvanceTo(simulator.get_context().get_time() + 2.0)
        meshcat.DeleteButton("Stop Simulation")
    else:
        simulator.AdvanceTo(0.1)

# %%
def teleop_2d_with_return_diagram():
    builder = DiagramBuilder() #system.framework
    
    time_step = 0.001
    station = builder.AddSystem(
        MakeManipulationStation(model_directives, time_step=time_step)
    )
    plant = station.GetSubsystemByName('plant')
    controller_plant = station.GetSubsystemByName(
        "iiwa_controller"
    ).get_multibody_plant_for_control()
    
    
    # still from pydrake
    # rendering part: 
    visualizer = MeshcatVisualizer.AddToBuilder(
        builder, station.GetOutputPort("query_object"), meshcat
    )
    meshcat.Set2dRenderMode(xmin=-0.25, xmax=1.5, ymin=-0.1, ymax=1.3)
    meshcat.DeleteAddedControls()
    
    # Differential Inverse Kinematics part ---> q' = J^-1 * r' : 
    # addIiwaDifferentialIK comes from manipulation 
    differential_ik = AddIiwaDifferentialIK(
        builder, 
        controller_plant, 
        frame=controller_plant.GetFrameByName('iiwa_link_7')
    )
    # connect system ---> note that it's done by port
    builder.Connect(
        differential_ik.get_output_port(), 
        station.GetInputPort("iiwa_position")
    )
    builder.Connect(
        station.GetOutputPort("iiwa_state_estimated"),
        differential_ik.GetInputPort("robot_state")
    )
    
    
    # Teleop widgets: 
    teleop = builder.AddSystem(
        
        MeshcatPoseSliders(
            meshcat, 
            min_range=MeshcatPoseSliders.MinRange(roll=0, x=-0.6, z=0.0),
            max_range=MeshcatPoseSliders.MaxRange(roll=2 * np.pi, x=0.8, z=1.1),
            value=MeshcatPoseSliders.Value(pitch=0, yaw=np.pi / 2, y=0),
            visible=MeshcatPoseSliders.Visible(pitch=False, yaw=False, y=False),
            decrement_keycode=MeshcatPoseSliders.DecrementKey(
                x="ArrowLeft",
                z="ArrowDown"),
            increment_keycode=MeshcatPoseSliders.IncrementKey(
                x="ArrowRight",
                z="ArrowUp"),
            body_index=plant.GetBodyByName("iiwa_link_7").index()
        )
    )
    
    builder.Connect(
        teleop.get_output_port(0),
        differential_ik.get_input_port(0)
    )
    builder.Connect(
        station.GetOutputPort('body_poses'), 
        teleop.GetInputPort('body_poses')
    )
    # from manipulation 
    wsg_teleop = builder.AddSystem(WsgButton(meshcat))
    builder.Connect(wsg_teleop.get_output_port(0), 
                   station.GetInputPort("wsg_position"))
    
    diagram = builder.Build()
    return diagram 
    
    
    
    
    if running_as_notebook:  # Then we're not just running as a test on CI.
        simulator.set_target_realtime_rate(1.0)
        meshcat.AddButton("Stop Simulation", "Escape")
        print("Press Escape to stop the simulation")
        while meshcat.GetButtonClicks("Stop Simulation") < 1:
            simulator.AdvanceTo(simulator.get_context().get_time() + 2.0)
        meshcat.DeleteButton("Stop Simulation")
    else:
        simulator.AdvanceTo(0.1)

# %%
teleop_2d()
# Out:
# Keyboard Controls:
# roll : KeyQ / KeyE
# x : ArrowLeft / ArrowRight
# z : ArrowDown / ArrowUp
# Press Space to open/close the gripper
# Press Escape to stop the simulation
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.867.
# WARNING:drake:Differential IK started finding solutions again at time 24.871000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.873.
# WARNING:drake:Differential IK started finding solutions again at time 24.874.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.876.
# WARNING:drake:Differential IK started finding solutions again at time 24.877.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.878.
# WARNING:drake:Differential IK started finding solutions again at time 24.879.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.881.
# WARNING:drake:Differential IK started finding solutions again at time 24.882.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.884.
# WARNING:drake:Differential IK started finding solutions again at time 24.885.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.887.
# WARNING:drake:Differential IK started finding solutions again at time 24.888.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.89.
# WARNING:drake:Differential IK started finding solutions again at time 24.891000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.893.
# WARNING:drake:Differential IK started finding solutions again at time 24.894000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.896.
# WARNING:drake:Differential IK started finding solutions again at time 24.897000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.899.
# WARNING:drake:Differential IK started finding solutions again at time 24.900000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.902.
# WARNING:drake:Differential IK started finding solutions again at time 24.903000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.905.
# WARNING:drake:Differential IK started finding solutions again at time 24.906.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.908.
# WARNING:drake:Differential IK started finding solutions again at time 24.909.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.91.
# WARNING:drake:Differential IK started finding solutions again at time 24.911.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.913.
# WARNING:drake:Differential IK started finding solutions again at time 24.914.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.916.
# WARNING:drake:Differential IK started finding solutions again at time 24.917.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.919.
# WARNING:drake:Differential IK started finding solutions again at time 24.92.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.922.
# WARNING:drake:Differential IK started finding solutions again at time 24.923000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.925.
# WARNING:drake:Differential IK started finding solutions again at time 24.926000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.928.
# WARNING:drake:Differential IK started finding solutions again at time 24.929000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.931.
# WARNING:drake:Differential IK started finding solutions again at time 24.932000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.934.
# WARNING:drake:Differential IK started finding solutions again at time 24.935000000000002.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.937.
# WARNING:drake:Differential IK started finding solutions again at time 24.938.
# WARNING:drake:Differential IK started returning status:"stuck" at time 24.939.
# WARNING:drake:Differential IK started finding solutions again at time 25.171.
# WARNING:drake:Differential IK started returning status:"stuck" at time 28.964000000000002.
# WARNING:drake:Differential IK started finding solutions again at time 32.058.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.328.
# WARNING:drake:Differential IK started finding solutions again at time 35.339.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.343.
# WARNING:drake:Differential IK started finding solutions again at time 35.344.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.346000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 35.347.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.349000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 35.35.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.352000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 35.353.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.356.
# WARNING:drake:Differential IK started finding solutions again at time 35.357.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.361000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 35.368.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.369.
# WARNING:drake:Differential IK started finding solutions again at time 35.387.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.388.
# WARNING:drake:Differential IK started finding solutions again at time 35.405.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.406.
# WARNING:drake:Differential IK started finding solutions again at time 35.424.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.425000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 35.443.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.444.
# WARNING:drake:Differential IK started finding solutions again at time 35.462.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.463.
# WARNING:drake:Differential IK started finding solutions again at time 35.481.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.482.
# WARNING:drake:Differential IK started finding solutions again at time 35.5.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.501.
# WARNING:drake:Differential IK started finding solutions again at time 35.519.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.52.
# WARNING:drake:Differential IK started finding solutions again at time 35.538000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.539.
# WARNING:drake:Differential IK started finding solutions again at time 35.558.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.559.
# WARNING:drake:Differential IK started finding solutions again at time 35.577.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.578.
# WARNING:drake:Differential IK started finding solutions again at time 35.596000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.597.
# WARNING:drake:Differential IK started finding solutions again at time 35.615.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.616.
# WARNING:drake:Differential IK started finding solutions again at time 35.634.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.635.
# WARNING:drake:Differential IK started finding solutions again at time 35.653.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.654.
# WARNING:drake:Differential IK started finding solutions again at time 35.672000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.673.
# WARNING:drake:Differential IK started finding solutions again at time 35.692.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.693.
# WARNING:drake:Differential IK started finding solutions again at time 35.711.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.712.
# WARNING:drake:Differential IK started finding solutions again at time 35.730000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.731.
# WARNING:drake:Differential IK started finding solutions again at time 35.749.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.75.
# WARNING:drake:Differential IK started finding solutions again at time 35.768.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.769.
# WARNING:drake:Differential IK started finding solutions again at time 35.787.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.788000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 35.805.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.806.
# WARNING:drake:Differential IK started finding solutions again at time 35.824.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.825.
# WARNING:drake:Differential IK started finding solutions again at time 35.842.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.843.
# WARNING:drake:Differential IK started finding solutions again at time 35.861000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.862.
# WARNING:drake:Differential IK started finding solutions again at time 35.879.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.88.
# WARNING:drake:Differential IK started finding solutions again at time 35.898.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.899.
# WARNING:drake:Differential IK started finding solutions again at time 35.916000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.917.
# WARNING:drake:Differential IK started finding solutions again at time 35.934.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.935.
# WARNING:drake:Differential IK started finding solutions again at time 35.952.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.953.
# WARNING:drake:Differential IK started finding solutions again at time 35.971000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.972.
# WARNING:drake:Differential IK started finding solutions again at time 35.989.
# WARNING:drake:Differential IK started returning status:"stuck" at time 35.99.
# WARNING:drake:Differential IK started finding solutions again at time 36.007.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.008.
# WARNING:drake:Differential IK started finding solutions again at time 36.026.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.027.
# WARNING:drake:Differential IK started finding solutions again at time 36.044000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.045.
# WARNING:drake:Differential IK started finding solutions again at time 36.063.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.064.
# WARNING:drake:Differential IK started finding solutions again at time 36.081.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.082.
# WARNING:drake:Differential IK started finding solutions again at time 36.1.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.101.
# WARNING:drake:Differential IK started finding solutions again at time 36.119.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.12.
# WARNING:drake:Differential IK started finding solutions again at time 36.13.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.131.
# WARNING:drake:Differential IK started finding solutions again at time 36.138.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.139.
# WARNING:drake:Differential IK started finding solutions again at time 36.145.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.146.
# WARNING:drake:Differential IK started finding solutions again at time 36.151.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.152.
# WARNING:drake:Differential IK started finding solutions again at time 36.156.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.157000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.161.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.162.
# WARNING:drake:Differential IK started finding solutions again at time 36.166000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.167.
# WARNING:drake:Differential IK started finding solutions again at time 36.171.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.172000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.177.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.178.
# WARNING:drake:Differential IK started finding solutions again at time 36.181.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.182.
# WARNING:drake:Differential IK started finding solutions again at time 36.186.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.187.
# WARNING:drake:Differential IK started finding solutions again at time 36.191.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.192.
# WARNING:drake:Differential IK started finding solutions again at time 36.196.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.197.
# WARNING:drake:Differential IK started finding solutions again at time 36.201.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.202.
# WARNING:drake:Differential IK started finding solutions again at time 36.206.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.207.
# WARNING:drake:Differential IK started finding solutions again at time 36.21.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.211.
# WARNING:drake:Differential IK started finding solutions again at time 36.215.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.216.
# WARNING:drake:Differential IK started finding solutions again at time 36.22.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.221000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.224000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.225.
# WARNING:drake:Differential IK started finding solutions again at time 36.229.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.230000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.234.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.235.
# WARNING:drake:Differential IK started finding solutions again at time 36.238.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.239.
# WARNING:drake:Differential IK started finding solutions again at time 36.242.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.243.
# WARNING:drake:Differential IK started finding solutions again at time 36.247.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.248.
# WARNING:drake:Differential IK started finding solutions again at time 36.251.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.252.
# WARNING:drake:Differential IK started finding solutions again at time 36.256.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.257.
# WARNING:drake:Differential IK started finding solutions again at time 36.26.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.261.
# WARNING:drake:Differential IK started finding solutions again at time 36.264.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.265.
# WARNING:drake:Differential IK started finding solutions again at time 36.269.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.27.
# WARNING:drake:Differential IK started finding solutions again at time 36.273.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.274.
# WARNING:drake:Differential IK started finding solutions again at time 36.277.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.278.
# WARNING:drake:Differential IK started finding solutions again at time 36.281.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.282000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.285000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.286.
# WARNING:drake:Differential IK started finding solutions again at time 36.289.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.29.
# WARNING:drake:Differential IK started finding solutions again at time 36.294000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.295.
# WARNING:drake:Differential IK started finding solutions again at time 36.298.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.299.
# WARNING:drake:Differential IK started finding solutions again at time 36.302.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.303.
# WARNING:drake:Differential IK started finding solutions again at time 36.306.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.307.
# WARNING:drake:Differential IK started finding solutions again at time 36.31.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.311.
# WARNING:drake:Differential IK started finding solutions again at time 36.314.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.315.
# WARNING:drake:Differential IK started finding solutions again at time 36.318.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.319.
# WARNING:drake:Differential IK started finding solutions again at time 36.321.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.322.
# WARNING:drake:Differential IK started finding solutions again at time 36.325.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.326.
# WARNING:drake:Differential IK started finding solutions again at time 36.329.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.33.
# WARNING:drake:Differential IK started finding solutions again at time 36.333.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.334.
# WARNING:drake:Differential IK started finding solutions again at time 36.337.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.338.
# WARNING:drake:Differential IK started finding solutions again at time 36.341.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.342.
# WARNING:drake:Differential IK started finding solutions again at time 36.344.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.345.
# WARNING:drake:Differential IK started finding solutions again at time 36.348.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.349000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.352000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.353.
# WARNING:drake:Differential IK started finding solutions again at time 36.355000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.356.
# WARNING:drake:Differential IK started finding solutions again at time 36.359.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.36.
# WARNING:drake:Differential IK started finding solutions again at time 36.363.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.364.
# WARNING:drake:Differential IK started finding solutions again at time 36.366.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.367.
# WARNING:drake:Differential IK started finding solutions again at time 36.37.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.371.
# WARNING:drake:Differential IK started finding solutions again at time 36.374.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.375.
# WARNING:drake:Differential IK started finding solutions again at time 36.377.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.378.
# WARNING:drake:Differential IK started finding solutions again at time 36.381.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.382.
# WARNING:drake:Differential IK started finding solutions again at time 36.384.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.385.
# WARNING:drake:Differential IK started finding solutions again at time 36.388.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.389.
# WARNING:drake:Differential IK started finding solutions again at time 36.391.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.392.
# WARNING:drake:Differential IK started finding solutions again at time 36.395.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.396.
# WARNING:drake:Differential IK started finding solutions again at time 36.398.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.399.
# WARNING:drake:Differential IK started finding solutions again at time 36.402.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.403.
# WARNING:drake:Differential IK started finding solutions again at time 36.405.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.406.
# WARNING:drake:Differential IK started finding solutions again at time 36.408.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.409.
# WARNING:drake:Differential IK started finding solutions again at time 36.412.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.413000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.415.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.416000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.418.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.419000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.422000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.423.
# WARNING:drake:Differential IK started finding solutions again at time 36.425000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.426.
# WARNING:drake:Differential IK started finding solutions again at time 36.428.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.429.
# WARNING:drake:Differential IK started finding solutions again at time 36.432.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.433.
# WARNING:drake:Differential IK started finding solutions again at time 36.435.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.436.
# WARNING:drake:Differential IK started finding solutions again at time 36.438.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.439.
# WARNING:drake:Differential IK started finding solutions again at time 36.441.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.442.
# WARNING:drake:Differential IK started finding solutions again at time 36.444.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.445.
# WARNING:drake:Differential IK started finding solutions again at time 36.448.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.449.
# WARNING:drake:Differential IK started finding solutions again at time 36.451.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.452.
# WARNING:drake:Differential IK started finding solutions again at time 36.454.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.455.
# WARNING:drake:Differential IK started finding solutions again at time 36.457.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.458.
# WARNING:drake:Differential IK started finding solutions again at time 36.46.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.461.
# WARNING:drake:Differential IK started finding solutions again at time 36.463.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.464.
# WARNING:drake:Differential IK started finding solutions again at time 36.466.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.467.
# WARNING:drake:Differential IK started finding solutions again at time 36.469.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.47.
# WARNING:drake:Differential IK started finding solutions again at time 36.472.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.473.
# WARNING:drake:Differential IK started finding solutions again at time 36.475.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.476.
# WARNING:drake:Differential IK started finding solutions again at time 36.478.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.479.
# WARNING:drake:Differential IK started finding solutions again at time 36.481.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.482.
# WARNING:drake:Differential IK started finding solutions again at time 36.484.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.485.
# WARNING:drake:Differential IK started finding solutions again at time 36.487.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.488.
# WARNING:drake:Differential IK started finding solutions again at time 36.49.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.491.
# WARNING:drake:Differential IK started finding solutions again at time 36.493.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.494.
# WARNING:drake:Differential IK started finding solutions again at time 36.496.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.497.
# WARNING:drake:Differential IK started finding solutions again at time 36.499.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.5.
# WARNING:drake:Differential IK started finding solutions again at time 36.502.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.503.
# WARNING:drake:Differential IK started finding solutions again at time 36.505.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.506.
# WARNING:drake:Differential IK started finding solutions again at time 36.508.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.509.
# WARNING:drake:Differential IK started finding solutions again at time 36.51.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.511.
# WARNING:drake:Differential IK started finding solutions again at time 36.513.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.514.
# WARNING:drake:Differential IK started finding solutions again at time 36.516.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.517.
# WARNING:drake:Differential IK started finding solutions again at time 36.519.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.52.
# WARNING:drake:Differential IK started finding solutions again at time 36.522.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.523.
# WARNING:drake:Differential IK started finding solutions again at time 36.524.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.525.
# WARNING:drake:Differential IK started finding solutions again at time 36.527.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.528.
# WARNING:drake:Differential IK started finding solutions again at time 36.53.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.531.
# WARNING:drake:Differential IK started finding solutions again at time 36.533.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.534.
# WARNING:drake:Differential IK started finding solutions again at time 36.535000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.536.
# WARNING:drake:Differential IK started finding solutions again at time 36.538000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.539.
# WARNING:drake:Differential IK started finding solutions again at time 36.541000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.542.
# WARNING:drake:Differential IK started finding solutions again at time 36.543.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.544000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.546.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.547000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.549.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.550000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.551.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.552.
# WARNING:drake:Differential IK started finding solutions again at time 36.554.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.555.
# WARNING:drake:Differential IK started finding solutions again at time 36.557.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.558.
# WARNING:drake:Differential IK started finding solutions again at time 36.559.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.56.
# WARNING:drake:Differential IK started finding solutions again at time 36.562.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.563.
# WARNING:drake:Differential IK started finding solutions again at time 36.564.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.565.
# WARNING:drake:Differential IK started finding solutions again at time 36.567.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.568.
# WARNING:drake:Differential IK started finding solutions again at time 36.569.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.57.
# WARNING:drake:Differential IK started finding solutions again at time 36.572.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.573.
# WARNING:drake:Differential IK started finding solutions again at time 36.574.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.575.
# WARNING:drake:Differential IK started finding solutions again at time 36.577.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.578.
# WARNING:drake:Differential IK started finding solutions again at time 36.579.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.58.
# WARNING:drake:Differential IK started finding solutions again at time 36.582.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.583.
# WARNING:drake:Differential IK started finding solutions again at time 36.584.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.585.
# WARNING:drake:Differential IK started finding solutions again at time 36.587.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.588.
# WARNING:drake:Differential IK started finding solutions again at time 36.589.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.59.
# WARNING:drake:Differential IK started finding solutions again at time 36.592.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.593.
# WARNING:drake:Differential IK started finding solutions again at time 36.594.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.595.
# WARNING:drake:Differential IK started finding solutions again at time 36.597.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.598.
# WARNING:drake:Differential IK started finding solutions again at time 36.599000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.6.
# WARNING:drake:Differential IK started finding solutions again at time 36.601.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.602000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.604.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.605000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.606.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.607.
# WARNING:drake:Differential IK started finding solutions again at time 36.608000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.609.
# WARNING:drake:Differential IK started finding solutions again at time 36.611000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.612.
# WARNING:drake:Differential IK started finding solutions again at time 36.613.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.614.
# WARNING:drake:Differential IK started finding solutions again at time 36.615.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.616.
# WARNING:drake:Differential IK started finding solutions again at time 36.618.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.619.
# WARNING:drake:Differential IK started finding solutions again at time 36.62.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.621.
# WARNING:drake:Differential IK started finding solutions again at time 36.622.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.623.
# WARNING:drake:Differential IK started finding solutions again at time 36.624.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.625.
# WARNING:drake:Differential IK started finding solutions again at time 36.627.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.628.
# WARNING:drake:Differential IK started finding solutions again at time 36.629.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.63.
# WARNING:drake:Differential IK started finding solutions again at time 36.631.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.632.
# WARNING:drake:Differential IK started finding solutions again at time 36.633.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.634.
# WARNING:drake:Differential IK started finding solutions again at time 36.635.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.636.
# WARNING:drake:Differential IK started finding solutions again at time 36.638.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.639.
# WARNING:drake:Differential IK started finding solutions again at time 36.64.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.641.
# WARNING:drake:Differential IK started finding solutions again at time 36.642.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.643.
# WARNING:drake:Differential IK started finding solutions again at time 36.644.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.645.
# WARNING:drake:Differential IK started finding solutions again at time 36.646.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.647.
# WARNING:drake:Differential IK started finding solutions again at time 36.648.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.649.
# WARNING:drake:Differential IK started finding solutions again at time 36.65.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.651.
# WARNING:drake:Differential IK started finding solutions again at time 36.652.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.653.
# WARNING:drake:Differential IK started finding solutions again at time 36.654.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.655.
# WARNING:drake:Differential IK started finding solutions again at time 36.657000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.658.
# WARNING:drake:Differential IK started finding solutions again at time 36.659.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.660000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.661.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.662.
# WARNING:drake:Differential IK started finding solutions again at time 36.663000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.664.
# WARNING:drake:Differential IK started finding solutions again at time 36.665.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.666000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.667.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.668.
# WARNING:drake:Differential IK started finding solutions again at time 36.669000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.67.
# WARNING:drake:Differential IK started finding solutions again at time 36.671.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.672000000000004.
# WARNING:drake:Differential IK started finding solutions again at time 36.673.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.674.
# WARNING:drake:Differential IK started finding solutions again at time 36.675000000000004.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.676.
# WARNING:drake:Differential IK started finding solutions again at time 36.677.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.679.
# WARNING:drake:Differential IK started finding solutions again at time 36.68.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.681.
# WARNING:drake:Differential IK started finding solutions again at time 36.682.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.683.
# WARNING:drake:Differential IK started finding solutions again at time 36.684.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.685.
# WARNING:drake:Differential IK started finding solutions again at time 36.686.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.687.
# WARNING:drake:Differential IK started finding solutions again at time 36.688.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.689.
# WARNING:drake:Differential IK started finding solutions again at time 36.69.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.691.
# WARNING:drake:Differential IK started finding solutions again at time 36.692.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.693.
# WARNING:drake:Differential IK started finding solutions again at time 36.694.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.696.
# WARNING:drake:Differential IK started finding solutions again at time 36.697.
# WARNING:drake:Differential IK started returning status:"stuck" at time 36.698.
# WARNING:drake:Differential IK started finding solutions again at time 36.7.

# %%
diagram = teleop_2d_with_return_diagram()
# Out:
# Keyboard Controls:
# roll : KeyQ / KeyE
# x : ArrowLeft / ArrowRight
# z : ArrowDown / ArrowUp
# Press Space to open/close the gripper

# %%
import pydot
from IPython.display import SVG

graph  = pydot.graph_from_dot_data(diagram.GetGraphvizString())[0]

# %%
graph.write_png('station_struct.png')
